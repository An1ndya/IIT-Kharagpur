# %% [markdown]
# <a href="https://colab.research.google.com/github/An1ndya/IIT-Kharagpur/blob/main/ML12_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('./dataset 2.csv')
df.head()

plt.scatter(df[df.columns[0]], df[df.columns[1]], df[df.columns[2]], df[df.columns[3]])
